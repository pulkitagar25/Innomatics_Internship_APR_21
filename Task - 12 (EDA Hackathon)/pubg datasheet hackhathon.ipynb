# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df1=pd.read_csv('data kills outliers')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-db3bbfee0506> in <module>
# ----> 1 df1=pd.read_csv('data kills outliers')
#
# c:\users\pulkit\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %% [markdown]
# due to memory issue(i make an new csv file in which i find and remove the outliers) and export that file as a data outliers.csv

# %%
df.shape

# %%
df['kills'].dtypes
# Out:
# dtype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111742 entries, 0 to 1111741
# Data columns (total 30 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Unnamed: 0       1111742 non-null  int64
#  1   Id               1111742 non-null  object
#  2   groupId          1111742 non-null  object
#  3   matchId          1111742 non-null  object
#  4   assists          1111742 non-null  int64
#  5   boosts           1111742 non-null  int64
#  6   damageDealt      1111742 non-null  float64
#  7   DBNOs            1111742 non-null  int64
#  8   headshotKills    1111742 non-null  int64
#  9   heals            1111742 non-null  int64
#  10  killPlace        1111742 non-null  int64
#  11  killPoints       1111742 non-null  int64
#  12  kills            1111742 non-null  int64
#  13  killStreaks      1111742 non-null  int64
#  14  longestKill      1111742 non-null  float64
#  15  matchDuration    1111742 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#          Unnamed: 0       assists        boosts   damageDealt         DBNOs  \
# count  1.111741e+06  1.111741e+06  1.111741e+06  1.111741e+06  1.111741e+06
# mean   2.224361e+06  2.336740e-01  1.106656e+00  1.307365e+02  6.573617e-01
# std    1.283879e+06  5.894031e-01  1.716051e+00  1.711756e+02  1.146023e+00
# min    6.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.112440e+06  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    2.223770e+06  0.000000e+00  0.000000e+00  8.411000e+01  0.000000e+00
# 75%    3.337955e+06  0.000000e+00  2.000000e+00  1.859000e+02  1.000000e+00
# max    4.446964e+06  1.700000e+01  2.400000e+01  5.990000e+03  3.500000e+01
#
#        headshotKills         heals     killPlace    killPoints         kills  \
# count   1.111741e+06  1.111741e+06  1.111741e+06  1.111741e+06  1.111741e+06
# mean    2.266490e-01  1.370349e+00  4.759566e+01  5.044306e+02  9.255105e-01
# ...

# %% [markdown]
# ## Visualization Separating the Categorical and Numerical data

# %%
numerical=df.select_dtypes(include=["int64"]).keys()
numerical
# Out:
# Index(['Unnamed: 0', 'assists', 'boosts', 'DBNOs', 'headshotKills', 'heals',
#        'killPlace', 'killPoints', 'kills', 'killStreaks', 'matchDuration',
#        'maxPlace', 'numGroups', 'rankPoints', 'revives', 'roadKills',
#        'teamKills', 'vehicleDestroys', 'weaponsAcquired', 'winPoints'],
#       dtype='object')

# %%
categorical = df.select_dtypes(include = ["object"]).keys()
categorical
# Out:
# Index(['Id', 'groupId', 'matchId', 'matchType'], dtype='object')

# %% [markdown]
# ## finding the outliers

# %%
df['kills'].dtypes
# Out:
# dtype('int64')

# %%
df['kills'].mean()
# Out:
# 0.9255105280816305

# %%
df['kills'].median()
# Out:
# 0.0

# %%
sb.boxplot(x=df['kills'])
print("before removing")
# Out:
# before removing

# %% [markdown]
# in  kills columns we found that kills< 30 can be consider as outliers beacuse only 27 columns have more than 30 kills.so we consider as a outliers and they can be treated as a outliiers.

# %%
sb.boxplot(x=df1['kills'])
print("after removing outliers")
# Out:
# after removing outliers

# %%
## matchDuration

# %%
df['matchDuration'].dtypes
# Out:
# dtype('int64')

# %%
df['matchDuration'].mean()
# Out:
# 1579.347832500706

# %%
df['matchDuration'].median()
# Out:
# 1438.0

# %%
sb.boxplot(x=df['matchDuration'])
print("before removing")
# Out:
# before removing

# %% [markdown]
# by plotting

# %%
sb.boxplot(x=df1['matchDuration'])
print("after removing")
# Out:
# after removing

# %%
##killPoints

# %%
df1['killPoints'].mean()
# Out:
# 504.430707317534

# %%
df1['killPoints'].median()
# Out:
# 0.0

# %%
sb.boxplot(x=df['rankPoints'])
print("before removing")
# Out:
# before removing

# %%
## headshotKills

# %%
sb.boxplot(x=df1['headshotKills'])
print("after removing")
# Out:
# after removing

# %% [markdown]
# ## finding the correlation

# %%
df1.corr()
# Out:
#                  Unnamed: 0   assists    boosts  damageDealt     DBNOs  \
# Unnamed: 0         1.000000  0.001534  0.000593     0.000115 -0.000208
# assists            0.001534  1.000000  0.307814     0.405784  0.302737
# boosts             0.000593  0.307814  1.000000     0.523373  0.358185
# damageDealt        0.000115  0.405784  0.523373     1.000000  0.739891
# DBNOs             -0.000208  0.302737  0.358185     0.739891  1.000000
# headshotKills      0.001290  0.197197  0.336294     0.611510  0.474451
# heals             -0.000604  0.228731  0.535454     0.343000  0.265509
# killPlace          0.000100 -0.290197 -0.554239    -0.679685 -0.555384
# killPoints         0.000054  0.038570  0.009023     0.050782  0.042240
# kills              0.000376  0.317372  0.504358     0.887528  0.712513
# killStreaks       -0.000267  0.242485  0.404042     0.704580  0.647468
# longestKill        0.001372  0.260639  0.421769     0.563999  0.449890
# ...

# %%
knock_dbno = df1['killPlace']
kills= df1['kills']

plt.figure(figsize=(15,10))
plt.scatter(knock_dbno,kills,  c = 'green', edgecolor = 'none', marker = '.')
plt.xlabel('killPlace')
plt.ylabel('kills')
plt.title('Correlation between killPlace and kills')
plt.show()

# %% [markdown]
# From here we observed the player who was killed early has less no. of kills. and we saw in correlation table that correaltion between rankpoint and killpoints is -0.9,hence player who has been killed early has less winning chances(due to less rank point).

# %%
knock_dbno = df1['DBNOs']
kills= df1['kills']

plt.figure(figsize=(15,10))
plt.scatter(knock_dbno,kills,  c = 'green', edgecolor = 'none', marker = '.')
plt.xlabel('DBNOs')
plt.ylabel('kills')
plt.title('Correlation between DBNOs and kills')
plt.show()

# %% [markdown]
# As we are here observing that the person who knock more player will kill more player. Here we are seeing almost directly proportional relation.

# %%
knock_dbno = df1['killPoints']
kills= df1['winPoints']

plt.figure(figsize=(15,10))
plt.scatter(knock_dbno,kills,  c = 'green', edgecolor = 'none', marker = '.')
plt.xlabel('killPoints')
plt.ylabel('winPoints')
plt.title('Correlation between killPoints and winPoints')
plt.show()

# %% [markdown]
# From this graph we get the players who has more number of killpoints then the chances of getting more winpoints.this is also linearly increasing graph.

# %%
f,ax = plt.subplots(figsize=(15, 15))
sb.heatmap(df1.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# By observing correlation table, we observed the player :--
#
# - more no. of kills contain more no. of headshots and killstreaks soo the winning chances of that player is getting high.
#
# - the player who has more no. of headshot gives more damageDealt.
#
# - the player who walked more distance used more boost
#
# - the player who walked more distance has high chance to killed earlier.

# %% [markdown]
# ### Analysing the Kill

# %%
print("On an average a person kills {:.4f} players, 99% of people have {} kills or less, while the maximum kills ever recorded is {}.".format(df1['kills'].mean(),df1['kills'].quantile(0.99), df1['kills'].max()))
# Out:
# On an average a person kills 0.9240 players, 99% of people have 7.0 kills or less, while the maximum kills ever recorded is 30.

# %%
data = df1.copy()
data.loc[data['kills'] > data['kills'].quantile(0.99)] = '8+'
plt.figure(figsize=(15,10))
sns.countplot(data['kills'].astype('str').sort_values())
plt.title("Kill Count",fontsize=15)
plt.show()

# %%
data = df1.copy()

data['dataCategories'] = pd.cut(data['kills'], [-1, 0, 2, 5, 10, 60], labels=['0_kills','1-2_kills', '3-5_kills', '6-10_kills', '10+_kills'])

plt.figure(figsize=(15,8))
sns.boxplot(x="dataCategories", y="winPlacePerc", data=data)
plt.show()

# %%
df1_types = df1[df1['matchType'].isin(['duo','duo-fpp','solo','solo-fpp','squad','squad-fpp'])]
plt.figure(figsize=(15,10))
sb.countplot(df1_types['matchType'].astype('str').sort_values())
plt.title("Match Types",fontsize=15)
plt.show()

# %%
print("A total of {} players ({:.4f}%) have won without a single kill!".format(len(df1[df1['winPlacePerc']==1]), 100*len(df1[df1['winPlacePerc']==1])/len(df1)))
df1 = df1[df1['damageDealt'] == 0].copy()
print("A total of {} players ({:.4f}%) have won without dealing damage!".format(len(df1[df1['winPlacePerc']==1]), 100*len(df1[df1['winPlacePerc']==1])/len(df1)))
# Out:
# A total of 31803 players (2.8613%) have won without a single kill!
# A total of 1194 players (0.3859%) have won without dealing damage!

# %% [markdown]
# ## Analysing Walk Distance

# %%
print("{} players ({:.4f}%) walked 0 meters. This means that either they die before even taking a step or they have just joined the game but are away from keyboard (more possible).".format(len(df1[df1['walkDistance'] == 0]), 100*len(df1[df1['walkDistance']==0])/len(df1)))
# Out:
# 22692 players (7.3344%) walked 0 meters. This means that either they die before even taking a step or they have just joined the game but are away from keyboard (more possible).

# %%
plt.figure(figsize=(15,10))
plt.title("Walking Distance Distribution",fontsize=15)
walkdistance = df1['walkDistance']
sns.distplot(walkdistance)

# %%
sns.jointplot(x="winPlacePerc", y="walkDistance",  data=df1, height=10, ratio=3, color="lime")
plt.show()

# %% [markdown]
# here we are ovserving those who walk more have less win percent and by this graph to win more number of times player have to walk less.

# %%
m_types = df1.loc[:,"matchType"].value_counts().to_frame().reset_index()
m_types.columns = ["Type","Count"]
m_types
# Out:
#                 Type   Count
# 0          squad-fpp  438749
# 1            duo-fpp  249927
# 2              squad  156573
# 3           solo-fpp  133853
# 4                duo   78038
# 5               solo   45679
# 6   normal-squad-fpp    4139
# 7           crashfpp    1581
# 8     normal-duo-fpp    1385
# 9           flaretpp     633
# 10   normal-solo-fpp     406
# 11          flarefpp     180
# 12      normal-squad     133
# 13          crashtpp      86
# 14       normal-solo      71
# 15        normal-duo      48

# %%
plt.figure(figsize=(15,8))
ticks = m_types.Type.values
ax = sns.barplot(x="Type", y="Count", data=m_types)
ax.set_xticklabels(ticks, rotation=60, fontsize=14)
ax.set_title("Match types")
plt.show()

# %%
m_types2 = df1.loc[:,"matchType"].value_counts().to_frame()
aggregated_squads = m_types2.loc[["squad-fpp","squad","normal-squad-fpp","normal-squad"],"matchType"].sum()
aggregated_duos = m_types2.loc[["duo-fpp","duo","normal-duo-fpp","normal-duo"],"matchType"].sum()
aggregated_solo = m_types2.loc[["solo-fpp","solo","normal-solo-fpp","normal-solo"],"matchType"].sum()
aggregated_mt = pd.DataFrame([aggregated_squads,aggregated_duos,aggregated_solo], index=["squad","duo","solo"], columns =["count"])
aggregated_mt
# Out:
#         count
# squad  599594
# duo    329398
# solo   180009

# %%
fig1, ax1 = plt.subplots(figsize=(5, 5))
labels = ['squad', 'duo', 'solo']

wedges, texts, autotexts = ax1.pie(aggregated_mt["count"],textprops=dict(color="w"), autopct='%1.1f%%', startangle=90)

ax1.axis('equal')
ax1.legend(wedges, labels,
          title="Types",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")
plt.show()

# %%
plt.figure(figsize=(15,8))
ax1 = sns.boxplot(x="kills",y="damageDealt", data = df1)
ax1.set_title("Damage Dealt vs. Number of Kills")
plt.show()

# %% [markdown]
# There is an obvious correlation between number of kills and damage dealt. We see also that there are some outliers, more in the lower range. As the number of kills increases number of outliers reduces - these players rather kill than wound enemies. The maximum kills is 72 which is much bigger than the wast majority of players scores.

# %% [markdown]
# ##### kill masters

# %%
df[df['kills']>50][["Id","assists","damageDealt","headshotKills","kills","longestKill"]]
# Out:
#                      Id  assists  damageDealt  headshotKills  kills  \
# 349163   97047ef60af1e7       11       5520.0              8     53
# 697393   1f6ceaa5140fb6       15       5468.0             13     56
# 758017   06308c988bf0c2        7       5990.0             64     72
# 1036315  2ade4369bccd12       12       5557.0              7     55
#
#          longestKill
# 349163         39.20
# 697393         79.06
# 758017         78.23
# 1036315        74.79

# %% [markdown]
# but we remove the playes as outliers because they are exceptional

# %% [markdown]
# ## Analysing Riding

# %%
print("An average person drives for {:.1f}m, 99% of people have drived {}m or less, while THE RIDER rode for {}m.".format(df1['rideDistance'].mean(), df1['rideDistance'].quantile(0.99), df1['rideDistance'].max()))
# Out:
# An average person drives for 359.2m, 99% of people have drived 5959.0m or less, while THE RIDER rode for 26220.0m.

# %%
sns.jointplot(x="winPlacePerc", y="rideDistance", data=df1, height=10, ratio=3)
plt.show()

# %% [markdown]
# Theoretically, if a player is able to destroy the vehicle it indicates the he/she is skilled. Let's check if this theory is correct.

# %%
plt.figure(figsize =(10,7))
sb.pointplot(x='vehicleDestroys',y='winPlacePerc',data=df1,color='lime',alpha=0.5)
plt.xlabel('Count of Vehicle Destroys',fontsize = 16,color='blue')
plt.ylabel('Win Percentage',fontsize = 16,color='blue')
plt.title('Vehicle Destroyed/ Win Ratio',fontsize = 20,color='blue')
plt.grid()
plt.show()

# %% [markdown]
# ## analysis healing and boosting

# %%
print("In the game on an average a person uses {:.1f} heal items, 99% of people use {} or less, while the maximun used is {}.".format(df1['heals'].mean(), df1['heals'].quantile(0.99), df1['heals'].max()))
print("In the game on an average a person uses {:.1f} boost items, 99% of people use {} or less, while the maximun used is {}.".format(df1['boosts'].mean(), df1['boosts'].quantile(0.99), df1['boosts'].max()))
# Out:
# In the game on an average a person uses 0.5 heal items, 99% of people use 8.0 or less, while the maximun used is 52.
# In the game on an average a person uses 0.3 boost items, 99% of people use 4.0 or less, while the maximun used is 24.

# %%
f,ax1 = plt.subplots(figsize =(15,7))
sb.pointplot(x='heals',y='winPlacePerc',data=df1,color='lime',alpha=0.8)
sb.pointplot(x='boosts',y='winPlacePerc',data=df1,color='blue',alpha=0.8)
plt.text(4,0.6,'Heals',color='lime',fontsize = 16,style = 'italic')
plt.text(4,0.55,'Boosts',color='blue',fontsize = 16,style = 'italic')
plt.xlabel('Number of heal/boost items',fontsize = 16,color='blue')
plt.ylabel('Win Percentage',fontsize = 16,color='blue')
plt.title('Heals vs Boosts',fontsize = 20,color='blue')
plt.grid()
plt.show()

# %% [markdown]
# #### Hypothesis

# %% [markdown]
# More Heals Used is Related to a Higher Final Position
# Hypothesis: If two players are trying to kill each other, the one that finally wins needs more healing. So more heals means a higher final position.
#
# A transformation of the data is needed, each row need to be a team rather than a single player, then filtering by the size of the team it's possible to get the alone players.

# %% [markdown]
# ### -----------------------------------------------------------THANK YOU--------------------------------------------------------------------------------
